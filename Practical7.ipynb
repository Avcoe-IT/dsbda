# %%
import matplotlib. pyplot as plt
import pandas as pd
import numpy as np

# %%
a = [1,2,3,4,5,6,5,4,3,2,1]
plt.plot(a)

# %%
b = [10,20,30,40,50,60,50,40,30,20,10]
plt.plot(a,b)

# %%
#Bar chart using Matplotlib
import seaborn as sns
#Creating the dataset
df = sns.load_dataset('titanic')
df=df.groupby('who')['fare'].sum().to_frame().reset_index()
#Creating the bar chart
plt.barh(df['who'],df['fare'],color = ['#F0F8FF','#E6E6FA','#B0E0E6'])
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
#Show the plot
plt.show()

# %%
#Bar chart using Seaborn
import seaborn as sns
#Creating bar plot
sns.barplot(x = 'fare',y = 'who',data = df ,palette = "Blues")
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Show the plot
plt.show()

# %%
# Column chart using Matplotlib
import seaborn as sns

# %%
#Creating the dataset
df = sns.load_dataset('titanic')
df=df.groupby('who')['fare'].sum().to_frame().reset_index()

# %%
#Creating the column plot
plt.bar(df['who'],df['fare'],color = ['#F0F8FF','#E6E6FA','#B0E0E6'])
# Out:
# <BarContainer object of 3 artists>

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
#Show the plot
plt.show()

# %%
#Column chart using Seaborn
#Reading the dataset
titanic_dataset = sns.load_dataset('titanic')

# %%
#Creating column chart
sns.barplot(x = 'who',y = 'fare',data = titanic_dataset,palette = "Blues")
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
# Show the plot
plt.show()

# %%
#Grouped bar chart using Matplotlib
#Creating the dataset
df = sns.load_dataset('titanic')
df_pivot = pd.pivot_table(df, values="fare",index="who",columns="class", aggfunc=np.mean)
# Out:
# C:\Users\DNYANESHWAR\AppData\Local\Temp\ipykernel_1840\3204337525.py:4: FutureWarning: The provided callable <function mean at 0x00000153BCE48900> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_pivot = pd.pivot_table(df, values="fare",index="who",columns="class", aggfunc=np.mean)

# %%
#Creating a grouped bar chart
ax = df_pivot.plot(kind="bar",alpha=0.5)

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
# Show the plot
plt.show()

# %%
#Grouped bar chart using seaborn
titanic_dataset = sns.load_dataset('titanic')

# %%
#Creating the bar plot grouped across classes
sns.barplot(x = 'who',y = 'fare',hue = 'class',data = titanic_dataset, palette = "Blues")
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
# Show the plot
plt.show()

# %%
# Stacked bar chart
#Creating the dataset
df = pd.DataFrame(columns=["A","B", "C","D"],
data=[["E",0,1,1],
["F",1,1,0],
["G",0,1,0]])
df.plot.bar(x='A', y=["B", "C","D"], stacked=True, width = 0.4,alpha=0.5)
# Out:
# <Axes: xlabel='A'>

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
#Show the plot
plt.show()

# %%
#Stacked bar chart using Seaborn
dataframe = pd.DataFrame(columns=["A","B", "C","D"],
data=[["E",0,1,1],
["F",1,1,0],
["G",0,1,0]])
dataframe.set_index('A').T.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
# Show the plot
plt.show()

# %%
#Line chart using Matplotlib
#Creating the dataset
df = sns.load_dataset("iris")
df=df.groupby('sepal_length')['sepal_width'].sum().to_frame().reset_index()

# %%
#Creating the line chart
plt.plot(df['sepal_length'], df['sepal_width'])

# %%
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# Text(0, 0.5, 'Y axis title')

# %%
#Show the plot
plt.show()

# %%
#pie chart using Seaborn
#Creating the dataset
cars = ['AUDI', 'BMW', 'NISSAN',
'TESLA', 'HYUNDAI', 'HONDA']
data = [20, 15, 15, 14, 16, 20]

# %%
#Creating the pie chart
plt.pie(data, labels = cars,colors = ['#F0F8FF','#E6E6FA','#B0E0E6','#7B68EE','#483D8B'])
# Out:
# ([<matplotlib.patches.Wedge at 0x153c3471a50>,
#   <matplotlib.patches.Wedge at 0x153c5d85f50>,
#   <matplotlib.patches.Wedge at 0x153c5d87310>,
#   <matplotlib.patches.Wedge at 0x153c5d94810>,
#   <matplotlib.patches.Wedge at 0x153c5d95a90>,
#   <matplotlib.patches.Wedge at 0x153c5d96f10>],
#  [Text(0.8899186877588753, 0.6465637858537406, 'AUDI'),
#   Text(-0.17207795223283848, 1.086457168210212, 'BMW'),
#   Text(-0.9801072140121811, 0.4993894763020951, 'NISSAN'),
#   Text(-0.9953097129848341, -0.46835731577295503, 'TESLA'),
#   Text(-0.20611935297230657, -1.0805159935559852, 'HYUNDAI'),
#   Text(0.8899187482945414, -0.6465637025335375, 'HONDA')])

# %%
#Adding the aesthetics
plt.title('Chart title')
# Out:
# Text(0.5, 1.0, 'Chart title')

# %%
#Show the plot
plt.show()

# %%
#Area chart using Matplotlib
#Reading the dataset
x=range(1,6)
y=[ [1,4,6,8,9], [2,2,7,10,12], [2,8,5,10,6] ]

# %%
#Creating the area chart
ax = plt.gca()
ax.stackplot(x, y, labels=['A','B','C'],alpha=0.5)
# Out:
# [<matplotlib.collections.PolyCollection at 0x153c4106e10>,
#  <matplotlib.collections.PolyCollection at 0x153c5e3b610>,
#  <matplotlib.collections.PolyCollection at 0x153c5af8c10>]

# %%
#Adding the aesthetics
plt.legend(loc='upper left')
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Y axis title')

# %%
#Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
